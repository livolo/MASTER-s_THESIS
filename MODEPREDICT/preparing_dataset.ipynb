# %%
import pandas as pd

# Load the three CSV files
details = pd.read_csv("details.csv")
images = pd.read_csv("Images_details.csv")
arc = pd.read_csv("Indian Biological Images Archive_labelling.csv")

# STEP 1: Merge details with arc (on Sample ID)
df1 = details.merge(arc, on="Sample ID", how="inner")

# STEP 2: Merge the result with image paths (on Experiment ID)
df2 = df1.merge(images, on="Experiment ID", how="inner")

# Rename columns for convenience
df2 = df2.rename(columns={
    "Image File Name (with path)": "image_path",
    "Ground truth label": "label"
})

# Final dataset with only useful columns
final_df = df2[["image_path", "label"]]

# Show first rows
print(final_df.head())
# Out:
#            image_path       label
# 0  a_data/0018_02.dcm  Not cancer
# 1  a_data/0018_03.dcm  Not cancer
# 2  a_data/0019_00.dcm  Not cancer
# 3  a_data/0019_01.dcm      Cancer
# 4  a_data/0019_02.dcm  Not cancer

# %%
# !pip install pydicom opencv-python pillow tqdm

# %%
import os

for root, dirs, files in os.walk(".", topdown=True):
    if "0000_00.dcm" in files:
        print("FOUND:", os.path.join(root, "0000_00.dcm"))
        break
# Out:
# FOUND: ./a_data/0000/0000_00.dcm

# %%
import os

def fix_path(row):
    wrong_path = row['image_path']                     # a_data/0018_02.dcm
    base = os.path.basename(wrong_path)                # 0018_02.dcm
    folder = base.split("_")[0]                        # 0018
    correct = f"a_data/{folder}/{base}"                # a_data/0018/0018_02.dcm
    return correct

final_df['correct_path'] = final_df.apply(fix_path, axis=1)
# Out:
# /tmp/ipykernel_112986/411589941.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['correct_path'] = final_df.apply(fix_path, axis=1)

# %%
import os

missing = []

for p in final_df['correct_path'].head(20):
    print(p, "→", os.path.exists(p))
# Out:
# a_data/0018/0018_02.dcm → True
# a_data/0018/0018_03.dcm → True
# a_data/0019/0019_00.dcm → True
# a_data/0019/0019_01.dcm → True
# a_data/0019/0019_02.dcm → True
# a_data/0019/0019_03.dcm → True
# a_data/0019/0019_04.dcm → True
# a_data/0019/0019_05.dcm → True
# a_data/0019/0019_06.dcm → True
# a_data/0019/0019_07.dcm → True
# a_data/0000/0000_00.dcm → True
# a_data/0000/0000_01.dcm → True
# a_data/0000/0000_02.dcm → True
# a_data/0000/0000_03.dcm → True
# a_data/0000/0000_04.dcm → True
# a_data/0000/0000_05.dcm → True
# a_data/0000/0000_06.dcm → True
# a_data/0000/0000_07.dcm → True
# a_data/0001/0001_00.dcm → True
# a_data/0001/0001_01.dcm → True

# %%
output_folder = "converted_png"
os.makedirs(output_folder, exist_ok=True)

for i, row in tqdm(final_df.iterrows(), total=len(final_df)):
    dicom_path = row['correct_path']
    png_name = os.path.basename(dicom_path).replace(".dcm", ".png")
    png_path = os.path.join(output_folder, png_name)
    dicom_to_png(dicom_path, png_path)
# Out:
#   0%|                                                                                                                                                                                                        | 1/3577 [00:00<15:32,  3.84it/s]
# Error: a_data/0018/0018_02.dcm Unable to decode the pixel data as the dataset's 'file_meta' has no (0002,0010) 'Transfer Syntax UID' element
# Error: a_data/0018/0018_03.dcm Unable to decode the pixel data as the dataset's 'file_meta' has no (0002,0010) 'Transfer Syntax UID' element
#   0%|▏                                                                                                                                                                                                       | 4/3577 [00:00<07:58,  7.47it/s]
# Error: a_data/0019/0019_00.dcm Unable to decode the pixel data as the dataset's 'file_meta' has no (0002,0010) 'Transfer Syntax UID' element
# ...

# %%
final_df = final_df.copy()     # remove slice-warning

final_df['correct_path'] = final_df.apply(fix_path, axis=1)

# %%
def dicom_to_png(dicom_path, png_path):
    try:
        dicom = pydicom.dcmread(dicom_path, force=True)

        # FIX missing Transfer Syntax
        if 'TransferSyntaxUID' not in dicom.file_meta:
            dicom.file_meta.TransferSyntaxUID = pydicom.uid.ImplicitVRLittleEndian

        img = dicom.pixel_array.astype(np.float32)

        # Normalize 0–255
        img = img - img.min()
        img = img / img.max()
        img = (img * 255).astype("uint8")

        cv2.imwrite(png_path, img)
        return True
    
    except Exception as e:
        print("Error:", dicom_path, e)
        return False

# %%
for i, row in tqdm(final_df.iterrows(), total=len(final_df)):
    dicom_path = row['correct_path']
    png_name = os.path.basename(dicom_path).replace(".dcm", ".png")
    png_path = os.path.join(output_folder, png_name)
    dicom_to_png(dicom_path, png_path)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3577/3577 [26:50<00:00,  2.22it/s]

# %%
import shutil

# Move cancer images
for i, row in cancer_df.iterrows():
    file = os.path.basename(row["correct_path"]).replace(".dcm", ".png")
    src = f"converted_png/{file}"
    dst = f"dataset/cancer/{file}"
    if os.path.exists(src):
        shutil.copy(src, dst)

# Move non-cancer images
for i, row in non_cancer_df.iterrows():
    file = os.path.basename(row["correct_path"]).replace(".dcm", ".png")
    src = f"converted_png/{file}"
    dst = f"dataset/non_cancer/{file}"
    if os.path.exists(src):
        shutil.copy(src, dst)

# %%
import pandas as pd

# Load all three CSVs
details = pd.read_csv("details.csv")
images = pd.read_csv("Images_details.csv")
arc = pd.read_csv("Indian Biological Images Archive_labelling.csv")

# STEP 1: Merge details with arc (on Sample ID)
df1 = details.merge(arc, on="Sample ID", how="inner")

# STEP 2: Merge with image.csv (on Experiment ID)
final_df = df1.merge(images, on="Experiment ID", how="inner")

# Rename useful columns
final_df = final_df.rename(columns={
    "Image File Name (with path)": "image_path",
    "Ground truth label": "label"
})

# Keep only important columns
final_df = final_df[["image_path", "label"]]

# Make a clean copy
final_df = final_df.copy()

# %%
import os

def fix_path(row):
    wrong_path = row['image_path']      # e.g. a_data/0018_02.dcm
    base = os.path.basename(wrong_path) # → 0018_02.dcm
    folder = base.split("_")[0]         # → 0018
    return f"a_data/{folder}/{base}"    # → a_data/0018/0018_02.dcm

final_df['correct_path'] = final_df.apply(fix_path, axis=1)

# %%
final_df.to_csv("final_df.csv", index=False)
print("final_df.csv saved successfully!")
# Out:
# final_df.csv saved successfully!

# %%
import pandas as pd

df = pd.read_csv("pseudo_boxes_filtered_clean.csv")

# Remove boxes that cover >60% of image
df = df[(df['xmax'] - df['xmin']) * (df['ymax'] - df['ymin']) < 0.6 * (4000 * 3000)]

# Remove boxes with width < 20 or height < 20 (tiny noise)
df = df[(df['xmax'] - df['xmin']) > 20]
df = df[(df['ymax'] - df['ymin']) > 20]

df.to_csv("pseudo_boxes_filtered_clean_v2.csv", index=False)
print("Saved cleaned pseudo boxes → pseudo_boxes_filtered_clean_v2.csv")
# Out:
# Saved cleaned pseudo boxes → pseudo_boxes_filtered_clean_v2.csv

# %%
import torch
ckpt = torch.load("fasterrcnn_mobile_best.pth")
print(ckpt.keys())
# Out:
# odict_keys(['backbone.body.0.0.weight', 'backbone.body.0.1.weight', 'backbone.body.0.1.bias', 'backbone.body.0.1.running_mean', 'backbone.body.0.1.running_var', 'backbone.body.1.block.0.0.weight', 'backbone.body.1.block.0.1.weight', 'backbone.body.1.block.0.1.bias', 'backbone.body.1.block.0.1.running_mean', 'backbone.body.1.block.0.1.running_var', 'backbone.body.1.block.1.0.weight', 'backbone.body.1.block.1.1.weight', 'backbone.body.1.block.1.1.bias', 'backbone.body.1.block.1.1.running_mean', 'backbone.body.1.block.1.1.running_var', 'backbone.body.2.block.0.0.weight', 'backbone.body.2.block.0.1.weight', 'backbone.body.2.block.0.1.bias', 'backbone.body.2.block.0.1.running_mean', 'backbone.body.2.block.0.1.running_var', 'backbone.body.2.block.1.0.weight', 'backbone.body.2.block.1.1.weight', 'backbone.body.2.block.1.1.bias', 'backbone.body.2.block.1.1.running_mean', 'backbone.body.2.block.1.1.running_var', 'backbone.body.2.block.2.0.weight', 'backbone.body.2.block.2.1.weight', 'backbone
# ...

# %%
pip install imbalanced-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [imbalanced-learn]1/2 [imbalanced-learn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
#Final Explanation in Simple Words
#A) With BIRADS → model performs excellent
#Because BIRADS is a clinician-assigned score
#It already encodes riskSo model accuracy becomes very high

#B) Without BIRADS → model performance drops a lot
#Because BIRADS was the strongest predictor
#Other features (age, density, view) are weak predictors
#So model becomes confused → more misclassifications
#6) What You Have Successfully Proven

#You demonstrated:

#✔ BIRADS is the strongest clinical predictor
#✔ Removing BIRADS reduces MLP performance dramatically
#✔ Other features alone are not enough for accurate cancer prediction
#✔ Your confusion matrices clearly show the difference

# %%
#1. CONFUSION MATRICES USED
#Without BIRADS

#TN = 316
#FP = 2
#FN = 1
#TP = 53

#With BIRADS removed (weaker model)

#TN = 214
#FP = 104
#FN = 33
#TP = 21

#2. Accuracy, Precision, Recall, F1-Score Calculation
#A) Without BIRADS
#Formula:

#Accuracy = (TP + TN) / Total

#Precision = TP / (TP + FP)

#Recall = TP / (TP + FN)

#F1 = 2 × (Precision × Recall) / (Precision + Recall)

#Values:

#Total = 316 + 2 + 1 + 53 = 372

#Metric	Value
#Accuracy	(316 + 53) / 372 = 0.9946 → 99.46%
#Precision	53 / (53 + 2) = 0.963
#Recall (Sensitivity)	53 / (53 + 1) = 0.981
#F1 Score	0.972

#➡ This is excellent performance.

#B) With BIRADS removed
#Values:

#Total = 214 + 104 + 33 + 21 = 372 (same number of samples)

#Metric	Value
#Accuracy	(214 + 21) / 372 = 0.631 → 63.1%
#Precision	21 / (21 + 104) = 0.168
#Recall (Sensitivity)	21 / (21 + 33) = 0.389
#F1 Score	0.235

#➡ This model performs very poorly.

#3. Final Comparison Table (Clean + Ready for Report)
#Comparison of MLP Performance With vs Without BIRADS
#Metric	Without BIRADS	With BIRADS Removed	Interpretation
#TN	316	214	Worse background classification
#FP	2	104	Huge rise → more false alarms
#FN	1	33	Missed cancers increased significantly
#TP	53	21	Correct cancer detection dropped
#Accuracy	99.46%	63.1%	Massive performance drop
#Precision	96.3%	16.8%	Positive predictions unreliable without BIRADS
#Recall	98.1%	38.9%	Model fails to detect cancer
#F1 Score	0.972	0.235	Model becomes almost ineffective
# 4. Statistical Interpretation (for your report)
#✔ BIRADS is the most predictive clinical feature, strongly correlated with cancer diagnosis.
#✔ Removing BIRADS causes:

#52× increase in false positives

#33× increase in false negatives

#Drop in F1 from 0.97 → 0.23

#Overall model accuracy falls from 99% → 63%

#✔ This proves:

#➡ BIRADS score is essential for model performance
#➡ Non-BIRADS features (age, density, view, laterality) are weak predictors alone
#➡ MLP heavily depends on BIRADS for discrimination
